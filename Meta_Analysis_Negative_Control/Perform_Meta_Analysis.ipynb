# %%
from statsmodels.stats.meta_analysis import combine_effects
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import warnings

# %%
os.chdir('/project/ssverma_shared/projects/Endometriosis/Endo_Subtyping_Heterogeneity/Meta_Analysis_Negative_Control/')

# %%
! snakemake -n all --quiet
# Out:
# Building DAG of jobs...
# Nothing to be done (all requested files are present and up to date).

# %%
phenos = ['endometriosis',
          'cluster_vs_controls_1',
          'cluster_vs_controls_2',
          'cluster_vs_controls_3',
          'cluster_vs_controls_4',
          'cluster_vs_controls_5']

# %%
pheno_ss = {p: [] for p in phenos}
pheno_ss_AFR_EUR = {p: [] for p in phenos}
pheno_ss_EUR = {p: [] for p in phenos}
pheno_ss_AFR = {p: [] for p in phenos}

biobanks = ['eMERGE', 'UKBB', 'PMBB', 'AOU']
# biobanks = ['eMERGE', 'PMBB', 'AOU']

for d in biobanks:
    for a in ['AFR', 'EUR']:
        if d == 'eMERGE' and a == 'ASIAN':
            continue
        for f in os.listdir(f'{d}_{a}/Sumstats/'):
            file_pheno = f.split('.')[0]
            if '0' in file_pheno:
                continue
            pheno_ss[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a != 'ASIAN':
                pheno_ss_AFR_EUR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a == 'EUR':
                pheno_ss_EUR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a == 'AFR':
                pheno_ss_AFR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')

# %%
eMERGE_id_map = pd.read_table('SNP_Lists/eMERGE_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']
UKBB_id_map = pd.read_table('SNP_Lists/UKBB_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']
AOU_id_map = pd.read_table('SNP_Lists/AOU_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']

# %%
use_allele = pd.read_table('PMBB_AFR/Sumstats/endometriosis.saige.gz', index_col='ID')['Allele2']
use_allele
# Out:
# ID
# chr1:21686033:C:T     T
# chr1:21720782:C:T     T
# chr1:21722171:C:T     T
# chr1:21772447:C:T     T
# chr1:21772448:C:T     T
#                      ..
# chr9:133370796:C:A    A
# chr9:133372523:G:C    C
# chr9:133402020:C:T    T
# chr9:133405414:T:G    G
# chr9:133405868:C:T    T
# Name: Allele2, Length: 11425, dtype: object

# %%
os.makedirs('Meta_Input/', exist_ok=True)

for p in phenos:
    if p == 'endometriosis':
        continue
    print(p)
    effs = pd.DataFrame()
    errs = pd.DataFrame()
    alleles = pd.DataFrame()
    afs = pd.DataFrame()
    Ns = pd.DataFrame()
    Neffs = pd.DataFrame()
    cases = pd.DataFrame()
    controls = pd.DataFrame()

    # Load data
    for ss_file in pheno_ss[p]:
        ss_dataset = ss_file.split('_')[0]
        ss_cohort = ss_file.split('/')[0]
        temp = pd.read_table(ss_file, nrows=None)
        temp = temp.rename(columns={'MarkerID': 'ID', 'p.value': 'P'})
        temp = temp.set_index('ID')
        temp['N'] = temp[['N_case', 'N_ctrl']].sum(axis=1)
        temp['Neff'] = temp['N'] * (temp['N_case'] / temp['N']) * (temp['N_ctrl'] / temp['N'])
        temp = temp[temp['AF_Allele2'] >= 0.01]
        temp = temp[['BETA', 'Allele2', 'SE', 'AF_Allele2', 'N', 'Neff', 'N_case', 'N_ctrl']].dropna()

        if ss_dataset == 'eMERGE':
            temp = temp[temp.index.isin(eMERGE_id_map.index)]
            temp = temp.rename(index=eMERGE_id_map)
        if ss_dataset == 'UKBB':
            temp = temp[temp.index.isin(UKBB_id_map.index)]
            temp = temp.rename(index=UKBB_id_map)
        if ss_dataset == 'AOU':
            temp = temp[temp.index.isin(AOU_id_map.index)]
            temp = temp.rename(index=AOU_id_map)

        effs[ss_cohort] = temp['BETA']
        errs[ss_cohort] = temp['SE']
        alleles[ss_cohort] = temp['Allele2']
        afs[ss_cohort] = temp['AF_Allele2']
        Ns[ss_cohort] = temp['N']
        Neffs[ss_cohort] = temp['Neff']
        cases[ss_cohort] = temp['N_case']
        controls[ss_cohort] = temp['N_ctrl']

    keep_vars = effs.index.intersection(use_allele.index)
    effs, errs, alleles  = effs.loc[keep_vars], errs.loc[keep_vars], alleles.loc[keep_vars]
    afs, Ns, Neffs = afs.loc[keep_vars], Ns.loc[keep_vars], Neffs.loc[keep_vars]
    cases, controls = cases.loc[keep_vars], controls.loc[keep_vars]

    # Now we have data to subset for meta-analysis
    effs = effs[effs.count(axis=1) > 1]
    errs = errs.loc[effs.index]
    alleles = alleles.loc[effs.index]
    afs = afs.loc[effs.index]
    Ns = Ns.loc[effs.index]
    Neffs = Neffs.loc[effs.index]
    cases = cases.loc[effs.index]
    controls = controls.loc[effs.index]

    use_allele_temp = use_allele.loc[alleles.index]
    use_allele_2D = np.broadcast_to(use_allele_temp.T, alleles.T.shape).T
    flip_coords = np.where(alleles.values != use_allele_2D)
    effs.values[flip_coords] = -effs.values[flip_coords]
    afs.values[flip_coords] = 1-afs.values[flip_coords]

    for cohort, effect_col in effs.items():
        table = pd.concat([effect_col, errs[cohort], use_allele], axis=1)
        table.columns = ['BETA', 'SE', 'A1']
        table.index.name = 'SNP'
        table['OR'] = np.exp(table['BETA'])
        table = table.dropna().reset_index()
        table[['CHR', 'BP']] = table['SNP'].str.replace('chr', '').str.split(':', expand=True)[[0, 1]]
        need_cols = ['CHR', 'BP', 'SNP', 'OR', 'SE', 'A1']
        table[need_cols].to_csv(f'Meta_Input/{cohort}.{p}.txt', sep='\t', index=False)

    # Use different combinations of groups
    for group, ss_dict in zip(['ALL', 'AFR_EUR', 'EUR', 'AFR'], [pheno_ss, pheno_ss_AFR_EUR, pheno_ss_EUR, pheno_ss_AFR]):
        print('\t', group)
        ss_group = ss_dict[p]
        cohorts = [f.split('/')[0] for f in ss_group]

        allele_counts = afs[cohorts] * Ns[cohorts]
        meta_af = allele_counts.sum(axis=1) / Ns.sum(axis=1)
        meta_var_info = pd.concat([meta_af, Ns.sum(axis=1), Neffs.sum(axis=1), cases.sum(axis=1), controls.sum(axis=1)], axis=1)
        meta_var_info.columns = ['Meta_AF', 'N', 'Neff_sum', 'Cases_sum', 'Controls_sum']
        meta_var_info['Phi'] = meta_var_info['Cases_sum'] / meta_var_info['N']
        meta_var_info['Neff_meta'] = meta_var_info['N'] * meta_var_info['Phi'] * (1-meta_var_info['Phi'])
        print(meta_var_info)
        meta_var_info.to_csv(f'Meta_Output/{p}.{group}.variant_info')

        if len(cohorts) < 2:
            continue

        plink_cmd_parts = ['plink', '--meta-analysis']
        plink_cmd_parts.extend([f'Meta_Input/{cohort}.{p}.txt' for cohort in cohorts])
        plink_cmd_parts.extend(['--out', f'Meta_Output/{p}.{group}.PLINK'])
        cmd = ' '.join(plink_cmd_parts)

        ! module load plink/1.90Beta6.18; {cmd}
# Out:
# cluster_vs_controls_1
# 	 ALL
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149865  412608.0  1585.633153     1599.0      411009.0
# chr1:21720782:C:T   0.151563  412608.0  1585.633153     1599.0      411009.0
# chr1:21722171:C:T   0.149566  412608.0  1585.633153     1599.0      411009.0
# chr1:21772447:C:T   0.150808  412608.0  1585.633153     1599.0      411009.0
# chr1:21772448:C:T   0.008299   76932.0   740.318733      749.0       76183.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138039  412608.0  1585.633153     1599.0      411009.0
# chr9:133372523:G:C  0.138316  412608.0  1585.633153     1599.0      411009.0
# chr9:133402020:C:T  0.133030  412608.0  1585.633153     1599.0      411009.0
# chr9:133405414:T:G  0.086512  412608.0  1585.633153     1599.0      411009.0
# chr9:133405868:C:T  0.081048  412608.0  1585.633153     1599.0      411009.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.003875  1592.803317
# chr1:21720782:C:T   0.003875  1592.803317
# chr1:21722171:C:T   0.003875  1592.803317
# chr1:21772447:C:T   0.003875  1592.803317
# chr1:21772448:C:T   0.009736   741.707833
# ...                      ...          ...
# chr9:133370796:C:A  0.003875  1592.803317
# chr9:133372523:G:C  0.003875  1592.803317
# chr9:133402020:C:T  0.003875  1592.803317
# chr9:133405414:T:G  0.003875  1592.803317
# chr9:133405868:C:T  0.003875  1592.803317
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.ALL.PLINK.meta .
# 	 AFR_EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149865  412608.0  1585.633153     1599.0      411009.0
# chr1:21720782:C:T   0.151563  412608.0  1585.633153     1599.0      411009.0
# chr1:21722171:C:T   0.149566  412608.0  1585.633153     1599.0      411009.0
# chr1:21772447:C:T   0.150808  412608.0  1585.633153     1599.0      411009.0
# chr1:21772448:C:T   0.008299   76932.0   740.318733      749.0       76183.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138039  412608.0  1585.633153     1599.0      411009.0
# chr9:133372523:G:C  0.138316  412608.0  1585.633153     1599.0      411009.0
# chr9:133402020:C:T  0.133030  412608.0  1585.633153     1599.0      411009.0
# chr9:133405414:T:G  0.086512  412608.0  1585.633153     1599.0      411009.0
# chr9:133405868:C:T  0.081048  412608.0  1585.633153     1599.0      411009.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.003875  1592.803317
# chr1:21720782:C:T   0.003875  1592.803317
# chr1:21722171:C:T   0.003875  1592.803317
# chr1:21772447:C:T   0.003875  1592.803317
# chr1:21772448:C:T   0.009736   741.707833
# ...                      ...          ...
# chr9:133370796:C:A  0.003875  1592.803317
# chr9:133372523:G:C  0.003875  1592.803317
# chr9:133402020:C:T  0.003875  1592.803317
# chr9:133405414:T:G  0.003875  1592.803317
# chr9:133405868:C:T  0.003875  1592.803317
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK.meta .
# 	 EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.143735  412608.0  1585.633153     1599.0      411009.0
# chr1:21720782:C:T   0.145923  412608.0  1585.633153     1599.0      411009.0
# chr1:21722171:C:T   0.145322  412608.0  1585.633153     1599.0      411009.0
# chr1:21772447:C:T   0.145198  412608.0  1585.633153     1599.0      411009.0
# chr1:21772448:C:T   0.000141   76932.0   740.318733      749.0       76183.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.128502  412608.0  1585.633153     1599.0      411009.0
# chr9:133372523:G:C  0.128768  412608.0  1585.633153     1599.0      411009.0
# chr9:133402020:C:T  0.124359  412608.0  1585.633153     1599.0      411009.0
# chr9:133405414:T:G  0.084538  412608.0  1585.633153     1599.0      411009.0
# chr9:133405868:C:T  0.079232  412608.0  1585.633153     1599.0      411009.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.003875  1592.803317
# chr1:21720782:C:T   0.003875  1592.803317
# chr1:21722171:C:T   0.003875  1592.803317
# chr1:21772447:C:T   0.003875  1592.803317
# chr1:21772448:C:T   0.009736   741.707833
# ...                      ...          ...
# chr9:133370796:C:A  0.003875  1592.803317
# chr9:133372523:G:C  0.003875  1592.803317
# chr9:133402020:C:T  0.003875  1592.803317
# chr9:133405414:T:G  0.003875  1592.803317
# chr9:133405868:C:T  0.003875  1592.803317
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9841 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.EUR.PLINK.meta .
# 	 AFR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.006130  412608.0  1585.633153     1599.0      411009.0
# chr1:21720782:C:T   0.005640  412608.0  1585.633153     1599.0      411009.0
# chr1:21722171:C:T   0.004244  412608.0  1585.633153     1599.0      411009.0
# chr1:21772447:C:T   0.005611  412608.0  1585.633153     1599.0      411009.0
# chr1:21772448:C:T   0.008158   76932.0   740.318733      749.0       76183.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.009536  412608.0  1585.633153     1599.0      411009.0
# chr9:133372523:G:C  0.009548  412608.0  1585.633153     1599.0      411009.0
# chr9:133402020:C:T  0.008671  412608.0  1585.633153     1599.0      411009.0
# chr9:133405414:T:G  0.001974  412608.0  1585.633153     1599.0      411009.0
# chr9:133405868:C:T  0.001816  412608.0  1585.633153     1599.0      411009.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.003875  1592.803317
# chr1:21720782:C:T   0.003875  1592.803317
# chr1:21722171:C:T   0.003875  1592.803317
# chr1:21772447:C:T   0.003875  1592.803317
# chr1:21772448:C:T   0.009736   741.707833
# ...                      ...          ...
# chr9:133370796:C:A  0.003875  1592.803317
# chr9:133372523:G:C  0.003875  1592.803317
# chr9:133402020:C:T  0.003875  1592.803317
# chr9:133405414:T:G  0.003875  1592.803317
# chr9:133405868:C:T  0.003875  1592.803317
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10321 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.AFR.PLINK.meta .
# cluster_vs_controls_2
# 	 ALL
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149925  413016.0  1948.428870     1964.0      411052.0
# chr1:21720782:C:T   0.151623  413016.0  1948.428870     1964.0      411052.0
# chr1:21722171:C:T   0.149616  413016.0  1948.428870     1964.0      411052.0
# chr1:21772447:C:T   0.150866  413016.0  1948.428870     1964.0      411052.0
# chr1:21772448:C:T   0.008285   76888.0   857.834478      869.0       76019.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138063  413016.0  1948.428870     1964.0      411052.0
# chr9:133372523:G:C  0.138342  413016.0  1948.428870     1964.0      411052.0
# chr9:133402020:C:T  0.133059  413016.0  1948.428870     1964.0      411052.0
# chr9:133405414:T:G  0.086560  413016.0  1948.428870     1964.0      411052.0
# chr9:133405868:C:T  0.081095  413016.0  1948.428870     1964.0      411052.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.004755  1954.660662
# chr1:21720782:C:T   0.004755  1954.660662
# chr1:21722171:C:T   0.004755  1954.660662
# chr1:21772447:C:T   0.004755  1954.660662
# chr1:21772448:C:T   0.011302   859.178428
# ...                      ...          ...
# chr9:133370796:C:A  0.004755  1954.660662
# chr9:133372523:G:C  0.004755  1954.660662
# chr9:133402020:C:T  0.004755  1954.660662
# chr9:133405414:T:G  0.004755  1954.660662
# chr9:133405868:C:T  0.004755  1954.660662
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.ALL.PLINK.meta .
# 	 AFR_EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149925  413016.0  1948.428870     1964.0      411052.0
# chr1:21720782:C:T   0.151623  413016.0  1948.428870     1964.0      411052.0
# chr1:21722171:C:T   0.149616  413016.0  1948.428870     1964.0      411052.0
# chr1:21772447:C:T   0.150866  413016.0  1948.428870     1964.0      411052.0
# chr1:21772448:C:T   0.008285   76888.0   857.834478      869.0       76019.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138063  413016.0  1948.428870     1964.0      411052.0
# chr9:133372523:G:C  0.138342  413016.0  1948.428870     1964.0      411052.0
# chr9:133402020:C:T  0.133059  413016.0  1948.428870     1964.0      411052.0
# chr9:133405414:T:G  0.086560  413016.0  1948.428870     1964.0      411052.0
# chr9:133405868:C:T  0.081095  413016.0  1948.428870     1964.0      411052.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.004755  1954.660662
# chr1:21720782:C:T   0.004755  1954.660662
# chr1:21722171:C:T   0.004755  1954.660662
# chr1:21772447:C:T   0.004755  1954.660662
# chr1:21772448:C:T   0.011302   859.178428
# ...                      ...          ...
# chr9:133370796:C:A  0.004755  1954.660662
# chr9:133372523:G:C  0.004755  1954.660662
# chr9:133402020:C:T  0.004755  1954.660662
# chr9:133405414:T:G  0.004755  1954.660662
# chr9:133405868:C:T  0.004755  1954.660662
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK.meta .
# 	 EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.143795  413016.0  1948.428870     1964.0      411052.0
# chr1:21720782:C:T   0.145979  413016.0  1948.428870     1964.0      411052.0
# chr1:21722171:C:T   0.145376  413016.0  1948.428870     1964.0      411052.0
# chr1:21772447:C:T   0.145252  413016.0  1948.428870     1964.0      411052.0
# chr1:21772448:C:T   0.000141   76888.0   857.834478      869.0       76019.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.128547  413016.0  1948.428870     1964.0      411052.0
# chr9:133372523:G:C  0.128815  413016.0  1948.428870     1964.0      411052.0
# chr9:133402020:C:T  0.124405  413016.0  1948.428870     1964.0      411052.0
# chr9:133405414:T:G  0.084585  413016.0  1948.428870     1964.0      411052.0
# chr9:133405868:C:T  0.079278  413016.0  1948.428870     1964.0      411052.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.004755  1954.660662
# chr1:21720782:C:T   0.004755  1954.660662
# chr1:21722171:C:T   0.004755  1954.660662
# chr1:21772447:C:T   0.004755  1954.660662
# chr1:21772448:C:T   0.011302   859.178428
# ...                      ...          ...
# chr9:133370796:C:A  0.004755  1954.660662
# chr9:133372523:G:C  0.004755  1954.660662
# chr9:133402020:C:T  0.004755  1954.660662
# chr9:133405414:T:G  0.004755  1954.660662
# chr9:133405868:C:T  0.004755  1954.660662
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9841 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.EUR.PLINK.meta .
# 	 AFR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.006130  413016.0  1948.428870     1964.0      411052.0
# chr1:21720782:C:T   0.005643  413016.0  1948.428870     1964.0      411052.0
# chr1:21722171:C:T   0.004240  413016.0  1948.428870     1964.0      411052.0
# chr1:21772447:C:T   0.005613  413016.0  1948.428870     1964.0      411052.0
# chr1:21772448:C:T   0.008144   76888.0   857.834478      869.0       76019.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.009515  413016.0  1948.428870     1964.0      411052.0
# chr9:133372523:G:C  0.009527  413016.0  1948.428870     1964.0      411052.0
# chr9:133402020:C:T  0.008653  413016.0  1948.428870     1964.0      411052.0
# chr9:133405414:T:G  0.001974  413016.0  1948.428870     1964.0      411052.0
# chr9:133405868:C:T  0.001817  413016.0  1948.428870     1964.0      411052.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.004755  1954.660662
# chr1:21720782:C:T   0.004755  1954.660662
# chr1:21722171:C:T   0.004755  1954.660662
# chr1:21772447:C:T   0.004755  1954.660662
# chr1:21772448:C:T   0.011302   859.178428
# ...                      ...          ...
# chr9:133370796:C:A  0.004755  1954.660662
# chr9:133372523:G:C  0.004755  1954.660662
# chr9:133402020:C:T  0.004755  1954.660662
# chr9:133405414:T:G  0.004755  1954.660662
# chr9:133405868:C:T  0.004755  1954.660662
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10322 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.AFR.PLINK.meta .
# cluster_vs_controls_3
# 	 ALL
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149905  413131.0  2123.341577     2138.0      410993.0
# chr1:21720782:C:T   0.151602  413131.0  2123.341577     2138.0      410993.0
# chr1:21722171:C:T   0.149603  413131.0  2123.341577     2138.0      410993.0
# chr1:21772447:C:T   0.150842  413131.0  2123.341577     2138.0      410993.0
# chr1:21772448:C:T   0.008319   76820.0   590.536743      596.0       76224.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138031  413131.0  2123.341577     2138.0      410993.0
# chr9:133372523:G:C  0.138308  413131.0  2123.341577     2138.0      410993.0
# chr9:133402020:C:T  0.133018  413131.0  2123.341577     2138.0      410993.0
# chr9:133405414:T:G  0.086543  413131.0  2123.341577     2138.0      410993.0
# chr9:133405868:C:T  0.081080  413131.0  2123.341577     2138.0      410993.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005175  2126.935606
# chr1:21720782:C:T   0.005175  2126.935606
# chr1:21722171:C:T   0.005175  2126.935606
# chr1:21772447:C:T   0.005175  2126.935606
# chr1:21772448:C:T   0.007758   591.375996
# ...                      ...          ...
# chr9:133370796:C:A  0.005175  2126.935606
# chr9:133372523:G:C  0.005175  2126.935606
# chr9:133402020:C:T  0.005175  2126.935606
# chr9:133405414:T:G  0.005175  2126.935606
# chr9:133405868:C:T  0.005175  2126.935606
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.ALL.PLINK.meta .
# 	 AFR_EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149905  413131.0  2123.341577     2138.0      410993.0
# chr1:21720782:C:T   0.151602  413131.0  2123.341577     2138.0      410993.0
# chr1:21722171:C:T   0.149603  413131.0  2123.341577     2138.0      410993.0
# chr1:21772447:C:T   0.150842  413131.0  2123.341577     2138.0      410993.0
# chr1:21772448:C:T   0.008319   76820.0   590.536743      596.0       76224.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138031  413131.0  2123.341577     2138.0      410993.0
# chr9:133372523:G:C  0.138308  413131.0  2123.341577     2138.0      410993.0
# chr9:133402020:C:T  0.133018  413131.0  2123.341577     2138.0      410993.0
# chr9:133405414:T:G  0.086543  413131.0  2123.341577     2138.0      410993.0
# chr9:133405868:C:T  0.081080  413131.0  2123.341577     2138.0      410993.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005175  2126.935606
# chr1:21720782:C:T   0.005175  2126.935606
# chr1:21722171:C:T   0.005175  2126.935606
# chr1:21772447:C:T   0.005175  2126.935606
# chr1:21772448:C:T   0.007758   591.375996
# ...                      ...          ...
# chr9:133370796:C:A  0.005175  2126.935606
# chr9:133372523:G:C  0.005175  2126.935606
# chr9:133402020:C:T  0.005175  2126.935606
# chr9:133405414:T:G  0.005175  2126.935606
# chr9:133405868:C:T  0.005175  2126.935606
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK.meta .
# 	 EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.143788  413131.0  2123.341577     2138.0      410993.0
# chr1:21720782:C:T   0.145972  413131.0  2123.341577     2138.0      410993.0
# chr1:21722171:C:T   0.145367  413131.0  2123.341577     2138.0      410993.0
# chr1:21772447:C:T   0.145242  413131.0  2123.341577     2138.0      410993.0
# chr1:21772448:C:T   0.000141   76820.0   590.536743      596.0       76224.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.128519  413131.0  2123.341577     2138.0      410993.0
# chr9:133372523:G:C  0.128784  413131.0  2123.341577     2138.0      410993.0
# chr9:133402020:C:T  0.124371  413131.0  2123.341577     2138.0      410993.0
# chr9:133405414:T:G  0.084573  413131.0  2123.341577     2138.0      410993.0
# chr9:133405868:C:T  0.079270  413131.0  2123.341577     2138.0      410993.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005175  2126.935606
# chr1:21720782:C:T   0.005175  2126.935606
# chr1:21722171:C:T   0.005175  2126.935606
# chr1:21772447:C:T   0.005175  2126.935606
# chr1:21772448:C:T   0.007758   591.375996
# ...                      ...          ...
# chr9:133370796:C:A  0.005175  2126.935606
# chr9:133372523:G:C  0.005175  2126.935606
# chr9:133402020:C:T  0.005175  2126.935606
# chr9:133405414:T:G  0.005175  2126.935606
# chr9:133405868:C:T  0.005175  2126.935606
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9840 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.EUR.PLINK.meta .
# 	 AFR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.006116  413131.0  2123.341577     2138.0      410993.0
# chr1:21720782:C:T   0.005630  413131.0  2123.341577     2138.0      410993.0
# chr1:21722171:C:T   0.004236  413131.0  2123.341577     2138.0      410993.0
# chr1:21772447:C:T   0.005600  413131.0  2123.341577     2138.0      410993.0
# chr1:21772448:C:T   0.008178   76820.0   590.536743      596.0       76224.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.009512  413131.0  2123.341577     2138.0      410993.0
# chr9:133372523:G:C  0.009524  413131.0  2123.341577     2138.0      410993.0
# chr9:133402020:C:T  0.008647  413131.0  2123.341577     2138.0      410993.0
# chr9:133405414:T:G  0.001970  413131.0  2123.341577     2138.0      410993.0
# chr9:133405868:C:T  0.001811  413131.0  2123.341577     2138.0      410993.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005175  2126.935606
# chr1:21720782:C:T   0.005175  2126.935606
# chr1:21722171:C:T   0.005175  2126.935606
# chr1:21772447:C:T   0.005175  2126.935606
# chr1:21772448:C:T   0.007758   591.375996
# ...                      ...          ...
# chr9:133370796:C:A  0.005175  2126.935606
# chr9:133372523:G:C  0.005175  2126.935606
# chr9:133402020:C:T  0.005175  2126.935606
# chr9:133405414:T:G  0.005175  2126.935606
# chr9:133405868:C:T  0.005175  2126.935606
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10322 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.AFR.PLINK.meta .
# cluster_vs_controls_4
# 	 ALL
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149812  412961.0  2062.814797     2088.0      410873.0
# chr1:21720782:C:T   0.151510  412961.0  2062.814797     2088.0      410873.0
# chr1:21722171:C:T   0.149511  412961.0  2062.814797     2088.0      410873.0
# chr1:21772447:C:T   0.150754  412961.0  2062.814797     2088.0      410873.0
# chr1:21772448:C:T   0.008251   77157.0  1036.996184     1055.0       76102.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138038  412961.0  2062.814797     2088.0      410873.0
# chr9:133372523:G:C  0.138314  412961.0  2062.814797     2088.0      410873.0
# chr9:133402020:C:T  0.133026  412961.0  2062.814797     2088.0      410873.0
# chr9:133405414:T:G  0.086533  412961.0  2062.814797     2088.0      410873.0
# chr9:133405868:C:T  0.081062  412961.0  2062.814797     2088.0      410873.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005056  2077.442722
# chr1:21720782:C:T   0.005056  2077.442722
# chr1:21722171:C:T   0.005056  2077.442722
# chr1:21772447:C:T   0.005056  2077.442722
# chr1:21772448:C:T   0.013673  1040.574543
# ...                      ...          ...
# chr9:133370796:C:A  0.005056  2077.442722
# chr9:133372523:G:C  0.005056  2077.442722
# chr9:133402020:C:T  0.005056  2077.442722
# chr9:133405414:T:G  0.005056  2077.442722
# chr9:133405868:C:T  0.005056  2077.442722
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.ALL.PLINK.meta .
# 	 AFR_EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.149812  412961.0  2062.814797     2088.0      410873.0
# chr1:21720782:C:T   0.151510  412961.0  2062.814797     2088.0      410873.0
# chr1:21722171:C:T   0.149511  412961.0  2062.814797     2088.0      410873.0
# chr1:21772447:C:T   0.150754  412961.0  2062.814797     2088.0      410873.0
# chr1:21772448:C:T   0.008251   77157.0  1036.996184     1055.0       76102.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.138038  412961.0  2062.814797     2088.0      410873.0
# chr9:133372523:G:C  0.138314  412961.0  2062.814797     2088.0      410873.0
# chr9:133402020:C:T  0.133026  412961.0  2062.814797     2088.0      410873.0
# chr9:133405414:T:G  0.086533  412961.0  2062.814797     2088.0      410873.0
# chr9:133405868:C:T  0.081062  412961.0  2062.814797     2088.0      410873.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005056  2077.442722
# chr1:21720782:C:T   0.005056  2077.442722
# chr1:21722171:C:T   0.005056  2077.442722
# chr1:21772447:C:T   0.005056  2077.442722
# chr1:21772448:C:T   0.013673  1040.574543
# ...                      ...          ...
# chr9:133370796:C:A  0.005056  2077.442722
# chr9:133372523:G:C  0.005056  2077.442722
# chr9:133402020:C:T  0.005056  2077.442722
# chr9:133405414:T:G  0.005056  2077.442722
# chr9:133405868:C:T  0.005056  2077.442722
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK.meta .
# 	 EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.143689  412961.0  2062.814797     2088.0      410873.0
# chr1:21720782:C:T   0.145878  412961.0  2062.814797     2088.0      410873.0
# chr1:21722171:C:T   0.145277  412961.0  2062.814797     2088.0      410873.0
# chr1:21772447:C:T   0.145152  412961.0  2062.814797     2088.0      410873.0
# chr1:21772448:C:T   0.000141   77157.0  1036.996184     1055.0       76102.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.128506  412961.0  2062.814797     2088.0      410873.0
# chr9:133372523:G:C  0.128770  412961.0  2062.814797     2088.0      410873.0
# chr9:133402020:C:T  0.124360  412961.0  2062.814797     2088.0      410873.0
# chr9:133405414:T:G  0.084555  412961.0  2062.814797     2088.0      410873.0
# chr9:133405868:C:T  0.079241  412961.0  2062.814797     2088.0      410873.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005056  2077.442722
# chr1:21720782:C:T   0.005056  2077.442722
# chr1:21722171:C:T   0.005056  2077.442722
# chr1:21772447:C:T   0.005056  2077.442722
# chr1:21772448:C:T   0.013673  1040.574543
# ...                      ...          ...
# chr9:133370796:C:A  0.005056  2077.442722
# chr9:133372523:G:C  0.005056  2077.442722
# chr9:133402020:C:T  0.005056  2077.442722
# chr9:133405414:T:G  0.005056  2077.442722
# chr9:133405868:C:T  0.005056  2077.442722
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9840 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.EUR.PLINK.meta .
# 	 AFR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.006123  412961.0  2062.814797     2088.0      410873.0
# chr1:21720782:C:T   0.005632  412961.0  2062.814797     2088.0      410873.0
# chr1:21722171:C:T   0.004234  412961.0  2062.814797     2088.0      410873.0
# chr1:21772447:C:T   0.005602  412961.0  2062.814797     2088.0      410873.0
# chr1:21772448:C:T   0.008110   77157.0  1036.996184     1055.0       76102.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.009532  412961.0  2062.814797     2088.0      410873.0
# chr9:133372523:G:C  0.009544  412961.0  2062.814797     2088.0      410873.0
# chr9:133402020:C:T  0.008666  412961.0  2062.814797     2088.0      410873.0
# chr9:133405414:T:G  0.001978  412961.0  2062.814797     2088.0      410873.0
# chr9:133405868:C:T  0.001820  412961.0  2062.814797     2088.0      410873.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.005056  2077.442722
# chr1:21720782:C:T   0.005056  2077.442722
# chr1:21722171:C:T   0.005056  2077.442722
# chr1:21772447:C:T   0.005056  2077.442722
# chr1:21772448:C:T   0.013673  1040.574543
# ...                      ...          ...
# chr9:133370796:C:A  0.005056  2077.442722
# chr9:133372523:G:C  0.005056  2077.442722
# chr9:133402020:C:T  0.005056  2077.442722
# chr9:133405414:T:G  0.005056  2077.442722
# chr9:133405868:C:T  0.005056  2077.442722
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10321 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.AFR.PLINK.meta .
# cluster_vs_controls_5
# 	 ALL
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.151858  405670.0  3085.128160     3113.0      402557.0
# chr1:21720782:C:T   0.153712  405670.0  3085.128160     3113.0      402557.0
# chr1:21722171:C:T   0.151937  405670.0  3085.128160     3113.0      402557.0
# chr1:21772447:C:T   0.152935  405670.0  3085.128160     3113.0      402557.0
# chr1:21772448:C:T   0.007134   63201.0   178.373624      179.0       63022.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.139170  405670.0  3085.128160     3113.0      402557.0
# chr9:133372523:G:C  0.139448  405670.0  3085.128160     3113.0      402557.0
# chr9:133402020:C:T  0.134237  405670.0  3085.128160     3113.0      402557.0
# chr9:133405414:T:G  0.088773  401398.0  3049.431531     3077.0      398321.0
# chr9:133405868:C:T  0.083178  401398.0  3049.431531     3077.0      398321.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.007674  3089.111694
# chr1:21720782:C:T   0.007674  3089.111694
# chr1:21722171:C:T   0.007674  3089.111694
# chr1:21772447:C:T   0.007674  3089.111694
# chr1:21772448:C:T   0.002832   178.493030
# ...                      ...          ...
# chr9:133370796:C:A  0.007674  3089.111694
# chr9:133372523:G:C  0.007674  3089.111694
# chr9:133402020:C:T  0.007674  3089.111694
# chr9:133405414:T:G  0.007666  3053.412615
# chr9:133405868:C:T  0.007666  3053.412615
#
# [10323 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10323 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.ALL.PLINK.meta .
# 	 AFR_EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.151858  405670.0  3085.128160     3113.0      402557.0
# chr1:21720782:C:T   0.153712  405670.0  3085.128160     3113.0      402557.0
# chr1:21722171:C:T   0.151937  405670.0  3085.128160     3113.0      402557.0
# chr1:21772447:C:T   0.152935  405670.0  3085.128160     3113.0      402557.0
# chr1:21772448:C:T   0.007134   63201.0   178.373624      179.0       63022.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.139170  405670.0  3085.128160     3113.0      402557.0
# chr9:133372523:G:C  0.139448  405670.0  3085.128160     3113.0      402557.0
# chr9:133402020:C:T  0.134237  405670.0  3085.128160     3113.0      402557.0
# chr9:133405414:T:G  0.088773  401398.0  3049.431531     3077.0      398321.0
# chr9:133405868:C:T  0.083178  401398.0  3049.431531     3077.0      398321.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.007674  3089.111694
# chr1:21720782:C:T   0.007674  3089.111694
# chr1:21722171:C:T   0.007674  3089.111694
# chr1:21772447:C:T   0.007674  3089.111694
# chr1:21772448:C:T   0.002832   178.493030
# ...                      ...          ...
# chr9:133370796:C:A  0.007674  3089.111694
# chr9:133372523:G:C  0.007674  3089.111694
# chr9:133402020:C:T  0.007674  3089.111694
# chr9:133405414:T:G  0.007666  3053.412615
# chr9:133405868:C:T  0.007666  3053.412615
#
# [10323 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10323 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK.meta .
# 	 EUR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.147143  405670.0  3085.128160     3113.0      402557.0
# chr1:21720782:C:T   0.149390  405670.0  3085.128160     3113.0      402557.0
# chr1:21722171:C:T   0.148771  405670.0  3085.128160     3113.0      402557.0
# chr1:21772447:C:T   0.148646  405670.0  3085.128160     3113.0      402557.0
# chr1:21772448:C:T   0.000172   63201.0   178.373624      179.0       63022.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.131496  405670.0  3085.128160     3113.0      402557.0
# chr9:133372523:G:C  0.131767  405670.0  3085.128160     3113.0      402557.0
# chr9:133402020:C:T  0.127249  405670.0  3085.128160     3113.0      402557.0
# chr9:133405414:T:G  0.087448  401398.0  3049.431531     3077.0      398321.0
# chr9:133405868:C:T  0.081953  401398.0  3049.431531     3077.0      398321.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.007674  3089.111694
# chr1:21720782:C:T   0.007674  3089.111694
# chr1:21722171:C:T   0.007674  3089.111694
# chr1:21772447:C:T   0.007674  3089.111694
# chr1:21772448:C:T   0.002832   178.493030
# ...                      ...          ...
# chr9:133370796:C:A  0.007674  3089.111694
# chr9:133372523:G:C  0.007674  3089.111694
# chr9:133402020:C:T  0.007674  3089.111694
# chr9:133405414:T:G  0.007666  3053.412615
# chr9:133405868:C:T  0.007666  3053.412615
#
# [10323 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9810 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.EUR.PLINK.meta .
# 	 AFR
#                      Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T   0.004716  405670.0  3085.128160     3113.0      402557.0
# chr1:21720782:C:T   0.004322  405670.0  3085.128160     3113.0      402557.0
# chr1:21722171:C:T   0.003166  405670.0  3085.128160     3113.0      402557.0
# chr1:21772447:C:T   0.004289  405670.0  3085.128160     3113.0      402557.0
# chr1:21772448:C:T   0.006962   63201.0   178.373624      179.0       63022.0
# ...                      ...       ...          ...        ...           ...
# chr9:133370796:C:A  0.007674  405670.0  3085.128160     3113.0      402557.0
# chr9:133372523:G:C  0.007682  405670.0  3085.128160     3113.0      402557.0
# chr9:133402020:C:T  0.006988  405670.0  3085.128160     3113.0      402557.0
# chr9:133405414:T:G  0.001325  401398.0  3049.431531     3077.0      398321.0
# chr9:133405868:C:T  0.001224  401398.0  3049.431531     3077.0      398321.0
#
#                          Phi    Neff_meta
# ID
# chr1:21686033:C:T   0.007674  3089.111694
# chr1:21720782:C:T   0.007674  3089.111694
# chr1:21722171:C:T   0.007674  3089.111694
# chr1:21772447:C:T   0.007674  3089.111694
# chr1:21772448:C:T   0.002832   178.493030
# ...                      ...          ...
# chr9:133370796:C:A  0.007674  3089.111694
# chr9:133372523:G:C  0.007674  3089.111694
# chr9:133402020:C:T  0.007674  3089.111694
# chr9:133405414:T:G  0.007666  3053.412615
# chr9:133405868:C:T  0.007666  3053.412615
#
# [10323 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10110 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.AFR.PLINK.meta .
