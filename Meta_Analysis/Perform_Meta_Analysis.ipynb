# %%
from statsmodels.stats.meta_analysis import combine_effects
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import warnings

# %%
os.chdir('/project/ssverma_shared/projects/Endometriosis/Endo_Subtyping_Heterogeneity/Meta_Analysis/')

# %%
! snakemake -n all --quiet
# Out:
# Building DAG of jobs...
# Job stats:
# job                        count    min threads    max threads
# -----------------------  -------  -------------  -------------
# align_to_PMBB                  4              1              1
# all                            1              1              1
# get_all_SNPs                   5              1              1
# lift_snplist_b37_to_b38        2              1              1
# total                         12              1              1

# %%
phenos = ['endometriosis',
          'cluster_vs_controls_1',
          'cluster_vs_controls_2',
          'cluster_vs_controls_3',
          'cluster_vs_controls_4',
          'cluster_vs_controls_5']

# %%
pheno_ss = {p: [] for p in phenos}
pheno_ss_AFR_EUR = {p: [] for p in phenos}
pheno_ss_EUR = {p: [] for p in phenos}
pheno_ss_AFR = {p: [] for p in phenos}

# biobanks = ['eMERGE', 'UKBB', 'PMBB', 'AOU']
biobanks = ['eMERGE', 'UKBB', 'PMBB', 'AOU', 'BioVU']
# biobanks = ['eMERGE', 'PMBB', 'AOU']

for d in biobanks:
    for a in ['AFR', 'EUR', 'ASIAN']:
        if d in ['eMERGE', 'BioVU'] and a == 'ASIAN':
            continue
        for f in os.listdir(f'{d}_{a}/Sumstats/'):
            file_pheno = f.split('.')[0]
            if '0' in file_pheno or 'nc' in file_pheno:
                continue
            pheno_ss[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a != 'ASIAN':
                pheno_ss_AFR_EUR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a == 'EUR':
                pheno_ss_EUR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')
            if a == 'AFR':
                pheno_ss_AFR[file_pheno].append(f'{d}_{a}/Sumstats/{f}')

# %%
eMERGE_id_map = pd.read_table('SNP_Lists/eMERGE_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']
UKBB_id_map = pd.read_table('SNP_Lists/UKBB_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']
AOU_id_map = pd.read_table('SNP_Lists/AOU_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']
BioVU_id_map = pd.read_table('SNP_Lists/BioVU_to_PMBB_ID_map.txt', index_col=['ID'])['PMBB_ID']

# %%
use_allele = pd.read_table('PMBB_AFR/Sumstats/endometriosis.saige.gz', index_col='ID')['Allele2']
use_allele
# Out:
# ID
# chr1:21686033:C:T     T
# chr1:21720782:C:T     T
# chr1:21722171:C:T     T
# chr1:21772447:C:T     T
# chr1:21772448:C:T     T
#                      ..
# chr9:133370796:C:A    A
# chr9:133372523:G:C    C
# chr9:133402020:C:T    T
# chr9:133405414:T:G    G
# chr9:133405868:C:T    T
# Name: Allele2, Length: 11425, dtype: object

# %%
os.makedirs('Meta_Input/', exist_ok=True)

for p in phenos:
    print(p)
    effs = pd.DataFrame()
    errs = pd.DataFrame()
    alleles = pd.DataFrame()
    afs = pd.DataFrame()
    Ns = pd.DataFrame()
    Neffs = pd.DataFrame()
    cases = pd.DataFrame()
    controls = pd.DataFrame()

    # Load data
    for ss_file in pheno_ss[p]:
        ss_dataset = ss_file.split('_')[0]
        ss_cohort = ss_file.split('/')[0]
        temp = pd.read_table(ss_file, nrows=None)
        temp = temp.rename(columns={'MarkerID': 'ID', 'p.value': 'P'})
        temp = temp.set_index('ID')
        temp['N'] = temp[['N_case', 'N_ctrl']].sum(axis=1)
        temp['Neff'] = temp['N'] * (temp['N_case'] / temp['N']) * (temp['N_ctrl'] / temp['N'])
        temp = temp[temp['AF_Allele2'] >= 0.01]
        temp = temp[['BETA', 'Allele2', 'SE', 'AF_Allele2', 'N', 'Neff', 'N_case', 'N_ctrl']].dropna()

        if ss_dataset == 'eMERGE':
            temp = temp[temp.index.isin(eMERGE_id_map.index)]
            temp = temp.rename(index=eMERGE_id_map)
        if ss_dataset == 'UKBB':
            temp = temp[temp.index.isin(UKBB_id_map.index)]
            temp = temp.rename(index=UKBB_id_map)
        if ss_dataset == 'AOU':
            temp = temp[temp.index.isin(AOU_id_map.index)]
            temp = temp.rename(index=AOU_id_map)
        if ss_dataset == 'BioVU':
            temp = temp[temp.index.isin(BioVU_id_map.index)]
            temp = temp.rename(index=BioVU_id_map)

        effs[ss_cohort] = temp['BETA']
        errs[ss_cohort] = temp['SE']
        alleles[ss_cohort] = temp['Allele2']
        afs[ss_cohort] = temp['AF_Allele2']
        Ns[ss_cohort] = temp['N']
        Neffs[ss_cohort] = temp['Neff']
        cases[ss_cohort] = temp['N_case']
        controls[ss_cohort] = temp['N_ctrl']

    keep_vars = effs.index.intersection(use_allele.index)
    effs, errs, alleles  = effs.loc[keep_vars], errs.loc[keep_vars], alleles.loc[keep_vars]
    afs, Ns, Neffs = afs.loc[keep_vars], Ns.loc[keep_vars], Neffs.loc[keep_vars]
    cases, controls = cases.loc[keep_vars], controls.loc[keep_vars]

    # Now we have data to subset for meta-analysis
    effs = effs[effs.count(axis=1) > 1]
    errs = errs.loc[effs.index]
    alleles = alleles.loc[effs.index]
    afs = afs.loc[effs.index]
    Ns = Ns.loc[effs.index]
    Neffs = Neffs.loc[effs.index]
    cases = cases.loc[effs.index]
    controls = controls.loc[effs.index]

    use_allele_temp = use_allele.loc[alleles.index]
    use_allele_2D = np.broadcast_to(use_allele_temp.T, alleles.T.shape).T
    flip_coords = np.where(alleles.values != use_allele_2D)
    effs.values[flip_coords] = -effs.values[flip_coords]
    afs.values[flip_coords] = 1-afs.values[flip_coords]

    for cohort, effect_col in effs.items():
        table = pd.concat([effect_col, errs[cohort], use_allele], axis=1)
        table.columns = ['BETA', 'SE', 'A1']
        table.index.name = 'SNP'
        table['OR'] = np.exp(table['BETA'])
        table = table.dropna().reset_index()
        table[['CHR', 'BP']] = table['SNP'].str.replace('chr', '').str.split(':', expand=True)[[0, 1]]
        need_cols = ['CHR', 'BP', 'SNP', 'OR', 'SE', 'A1']
        table[need_cols].to_csv(f'Meta_Input/{cohort}.{p}.txt', sep='\t', index=False)

    # Use different combinations of groups
    for group, ss_dict in zip(['ALL', 'AFR_EUR', 'EUR', 'AFR'], [pheno_ss, pheno_ss_AFR_EUR, pheno_ss_EUR, pheno_ss_AFR]):
        print('\t', group)
        ss_group = ss_dict[p]
        cohorts = [f.split('/')[0] for f in ss_group]

        allele_counts = afs[cohorts] * Ns[cohorts]
        meta_af = allele_counts.sum(axis=1) / Ns.sum(axis=1)
        meta_var_info = pd.concat([meta_af, Ns.sum(axis=1), Neffs.sum(axis=1), cases.sum(axis=1), controls.sum(axis=1)], axis=1)
        meta_var_info.columns = ['Meta_AF', 'N', 'Neff_sum', 'Cases_sum', 'Controls_sum']
        meta_var_info['Phi'] = meta_var_info['Cases_sum'] / meta_var_info['N']
        meta_var_info['Neff_meta'] = meta_var_info['N'] * meta_var_info['Phi'] * (1-meta_var_info['Phi'])
        print(meta_var_info)
        meta_var_info.to_csv(f'Meta_Output/{p}.{group}.variant_info')

        if len(cohorts) < 2:
            continue

        plink_cmd_parts = ['plink', '--meta-analysis']
        plink_cmd_parts.extend([f'Meta_Input/{cohort}.{p}.txt' for cohort in cohorts])
        plink_cmd_parts.extend(['--out', f'Meta_Output/{p}.{group}.PLINK'])
        cmd = ' '.join(plink_cmd_parts)

        ! module load plink/1.90Beta6.18; {cmd}
# Out:
# endometriosis
# 	 ALL
#                     Meta_AF         N      Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.147609  447268.0  11336.722013    11724.0      435544.0
# chr1:21720782:C:T  0.149142  447268.0  11336.722013    11724.0      435544.0
# chr1:21722171:C:T  0.150214  433998.0  10838.942359    11206.0      422792.0
# chr1:21772447:C:T  0.148428  447268.0  11336.722013    11724.0      435544.0
# chr1:21772448:C:T  0.008162   79200.0   3311.068933     3489.0       75711.0
# ...                     ...       ...           ...        ...           ...
# chr19:8697017:A:T  0.386220  447268.0  11336.722013    11724.0      435544.0
# chr19:8702698:C:T  0.384135  447268.0  11336.722013    11724.0      435544.0
# chr19:8703043:G:A  0.384038  447268.0  11336.722013    11724.0      435544.0
# chr19:8703125:G:T  0.698780  447268.0  11336.722013    11724.0      435544.0
# chr19:8704019:C:T  0.151149  433998.0  10838.942359    11206.0      422792.0
#
#                         Phi     Neff_meta
# ID
# chr1:21686033:C:T  0.026212  11416.684976
# chr1:21720782:C:T  0.026212  11416.684976
# chr1:21722171:C:T  0.025820  10916.656648
# chr1:21772447:C:T  0.026212  11416.684976
# chr1:21772448:C:T  0.044053   3335.298977
# ...                     ...           ...
# chr19:8697017:A:T  0.026212  11416.684976
# chr19:8702698:C:T  0.026212  11416.684976
# chr19:8703043:G:A  0.026212  11416.684976
# chr19:8703125:G:T  0.026212  11416.684976
# chr19:8704019:C:T  0.025820  10916.656648
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/endometriosis.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.endometriosis.txt Meta_Input/eMERGE_EUR.endometriosis.txt Meta_Input/UKBB_AFR.endometriosis.txt Meta_Input/UKBB_EUR.endometriosis.txt Meta_Input/UKBB_ASIAN.endometriosis.txt Meta_Input/PMBB_AFR.endometriosis.txt Meta_Input/PMBB_EUR.endometriosis.txt Meta_Input/PMBB_ASIAN.endometriosis.txt Meta_Input/AOU_AFR.endometriosis.txt Meta_Input/AOU_EUR.endometriosis.txt Meta_Input/AOU_ASIAN.endometriosis.txt Meta_Input/BioVU_AFR.endometriosis.txt Meta_Input/BioVU_EUR.endometriosis.txt
#   --out Meta_Output/endometriosis.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10494 variants processed; results written to
# Meta_Output/endometriosis.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N      Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142433  447268.0  11336.722013    11724.0      435544.0
# chr1:21720782:C:T  0.144013  447268.0  11336.722013    11724.0      435544.0
# chr1:21722171:C:T  0.144933  433998.0  10838.942359    11206.0      422792.0
# chr1:21772447:C:T  0.143287  447268.0  11336.722013    11724.0      435544.0
# chr1:21772448:C:T  0.008162   79200.0   3311.068933     3489.0       75711.0
# ...                     ...       ...           ...        ...           ...
# chr19:8697017:A:T  0.372314  447268.0  11336.722013    11724.0      435544.0
# chr19:8702698:C:T  0.370577  447268.0  11336.722013    11724.0      435544.0
# chr19:8703043:G:A  0.370482  447268.0  11336.722013    11724.0      435544.0
# chr19:8703125:G:T  0.681085  447268.0  11336.722013    11724.0      435544.0
# chr19:8704019:C:T  0.147893  433998.0  10838.942359    11206.0      422792.0
#
#                         Phi     Neff_meta
# ID
# chr1:21686033:C:T  0.026212  11416.684976
# chr1:21720782:C:T  0.026212  11416.684976
# chr1:21722171:C:T  0.025820  10916.656648
# chr1:21772447:C:T  0.026212  11416.684976
# chr1:21772448:C:T  0.044053   3335.298977
# ...                     ...           ...
# chr19:8697017:A:T  0.026212  11416.684976
# chr19:8702698:C:T  0.026212  11416.684976
# chr19:8703043:G:A  0.026212  11416.684976
# chr19:8703125:G:T  0.026212  11416.684976
# chr19:8704019:C:T  0.025820  10916.656648
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/endometriosis.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.endometriosis.txt Meta_Input/eMERGE_EUR.endometriosis.txt Meta_Input/UKBB_AFR.endometriosis.txt Meta_Input/UKBB_EUR.endometriosis.txt Meta_Input/PMBB_AFR.endometriosis.txt Meta_Input/PMBB_EUR.endometriosis.txt Meta_Input/AOU_AFR.endometriosis.txt Meta_Input/AOU_EUR.endometriosis.txt Meta_Input/BioVU_AFR.endometriosis.txt Meta_Input/BioVU_EUR.endometriosis.txt
#   --out Meta_Output/endometriosis.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10494 variants processed; results written to
# Meta_Output/endometriosis.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N      Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.136033  447268.0  11336.722013    11724.0      435544.0
# chr1:21720782:C:T  0.138149  447268.0  11336.722013    11724.0      435544.0
# chr1:21722171:C:T  0.140663  433998.0  10838.942359    11206.0      422792.0
# chr1:21772447:C:T  0.137471  447268.0  11336.722013    11724.0      435544.0
# chr1:21772448:C:T  0.000137   79200.0   3311.068933     3489.0       75711.0
# ...                     ...       ...           ...        ...           ...
# chr19:8697017:A:T  0.338788  447268.0  11336.722013    11724.0      435544.0
# chr19:8702698:C:T  0.337217  447268.0  11336.722013    11724.0      435544.0
# chr19:8703043:G:A  0.337122  447268.0  11336.722013    11724.0      435544.0
# chr19:8703125:G:T  0.608760  447268.0  11336.722013    11724.0      435544.0
# chr19:8704019:C:T  0.140042  433998.0  10838.942359    11206.0      422792.0
#
#                         Phi     Neff_meta
# ID
# chr1:21686033:C:T  0.026212  11416.684976
# chr1:21720782:C:T  0.026212  11416.684976
# chr1:21722171:C:T  0.025820  10916.656648
# chr1:21772447:C:T  0.026212  11416.684976
# chr1:21772448:C:T  0.044053   3335.298977
# ...                     ...           ...
# chr19:8697017:A:T  0.026212  11416.684976
# chr19:8702698:C:T  0.026212  11416.684976
# chr19:8703043:G:A  0.026212  11416.684976
# chr19:8703125:G:T  0.026212  11416.684976
# chr19:8704019:C:T  0.025820  10916.656648
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/endometriosis.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.endometriosis.txt Meta_Input/UKBB_EUR.endometriosis.txt Meta_Input/PMBB_EUR.endometriosis.txt Meta_Input/AOU_EUR.endometriosis.txt Meta_Input/BioVU_EUR.endometriosis.txt
#   --out Meta_Output/endometriosis.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9842 variants processed; results written to
# Meta_Output/endometriosis.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N      Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.006400  447268.0  11336.722013    11724.0      435544.0
# chr1:21720782:C:T  0.005864  447268.0  11336.722013    11724.0      435544.0
# chr1:21722171:C:T  0.004270  433998.0  10838.942359    11206.0      422792.0
# chr1:21772447:C:T  0.005816  447268.0  11336.722013    11724.0      435544.0
# chr1:21772448:C:T  0.008025   79200.0   3311.068933     3489.0       75711.0
# ...                     ...       ...           ...        ...           ...
# chr19:8697017:A:T  0.033526  447268.0  11336.722013    11724.0      435544.0
# chr19:8702698:C:T  0.033361  447268.0  11336.722013    11724.0      435544.0
# chr19:8703043:G:A  0.033360  447268.0  11336.722013    11724.0      435544.0
# chr19:8703125:G:T  0.072325  447268.0  11336.722013    11724.0      435544.0
# chr19:8704019:C:T  0.007851  433998.0  10838.942359    11206.0      422792.0
#
#                         Phi     Neff_meta
# ID
# chr1:21686033:C:T  0.026212  11416.684976
# chr1:21720782:C:T  0.026212  11416.684976
# chr1:21722171:C:T  0.025820  10916.656648
# chr1:21772447:C:T  0.026212  11416.684976
# chr1:21772448:C:T  0.044053   3335.298977
# ...                     ...           ...
# chr19:8697017:A:T  0.026212  11416.684976
# chr19:8702698:C:T  0.026212  11416.684976
# chr19:8703043:G:A  0.026212  11416.684976
# chr19:8703125:G:T  0.026212  11416.684976
# chr19:8704019:C:T  0.025820  10916.656648
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/endometriosis.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.endometriosis.txt Meta_Input/UKBB_AFR.endometriosis.txt Meta_Input/PMBB_AFR.endometriosis.txt Meta_Input/AOU_AFR.endometriosis.txt Meta_Input/BioVU_AFR.endometriosis.txt
#   --out Meta_Output/endometriosis.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10321 variants processed; results written to
# Meta_Output/endometriosis.AFR.PLINK.meta .
# cluster_vs_controls_1
# 	 ALL
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142949  447457.0  1749.805584     1764.0      445693.0
# chr1:21720782:C:T  0.144770  447457.0  1749.805584     1764.0      445693.0
# chr1:21722171:C:T  0.149530  413317.0  1585.664794     1599.0      411718.0
# chr1:21772447:C:T  0.144096  447457.0  1749.805584     1764.0      445693.0
# chr1:21772448:C:T  0.008283   77092.0   740.322759      749.0       76343.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373124  447457.0  1749.805584     1764.0      445693.0
# chr19:8702698:C:T  0.371435  447457.0  1749.805584     1764.0      445693.0
# chr19:8703043:G:A  0.371232  447457.0  1749.805584     1764.0      445693.0
# chr19:8703125:G:T  0.684624  447457.0  1749.805584     1764.0      445693.0
# chr19:8704019:C:T  0.152263  413317.0  1585.664794     1599.0      411718.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.003942  1757.045821
# chr1:21720782:C:T  0.003942  1757.045821
# chr1:21722171:C:T  0.003869  1592.813947
# chr1:21772447:C:T  0.003942  1757.045821
# chr1:21772448:C:T  0.009716   741.722967
# ...                     ...          ...
# chr19:8697017:A:T  0.003942  1757.045821
# chr19:8702698:C:T  0.003942  1757.045821
# chr19:8703043:G:A  0.003942  1757.045821
# chr19:8703125:G:T  0.003942  1757.045821
# chr19:8704019:C:T  0.003869  1592.813947
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_AFR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_ASIAN.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt Meta_Input/BioVU_AFR.cluster_vs_controls_1.txt Meta_Input/BioVU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10494 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142949  447457.0  1749.805584     1764.0      445693.0
# chr1:21720782:C:T  0.144770  447457.0  1749.805584     1764.0      445693.0
# chr1:21722171:C:T  0.149530  413317.0  1585.664794     1599.0      411718.0
# chr1:21772447:C:T  0.144096  447457.0  1749.805584     1764.0      445693.0
# chr1:21772448:C:T  0.008283   77092.0   740.322759      749.0       76343.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373124  447457.0  1749.805584     1764.0      445693.0
# chr19:8702698:C:T  0.371435  447457.0  1749.805584     1764.0      445693.0
# chr19:8703043:G:A  0.371232  447457.0  1749.805584     1764.0      445693.0
# chr19:8703125:G:T  0.684624  447457.0  1749.805584     1764.0      445693.0
# chr19:8704019:C:T  0.152263  413317.0  1585.664794     1599.0      411718.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.003942  1757.045821
# chr1:21720782:C:T  0.003942  1757.045821
# chr1:21722171:C:T  0.003869  1592.813947
# chr1:21772447:C:T  0.003942  1757.045821
# chr1:21772448:C:T  0.009716   741.722967
# ...                     ...          ...
# chr19:8697017:A:T  0.003942  1757.045821
# chr19:8702698:C:T  0.003942  1757.045821
# chr19:8703043:G:A  0.003942  1757.045821
# chr19:8703125:G:T  0.003942  1757.045821
# chr19:8704019:C:T  0.003869  1592.813947
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_AFR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt Meta_Input/BioVU_AFR.cluster_vs_controls_1.txt Meta_Input/BioVU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10494 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.137027  447457.0  1749.805584     1764.0      445693.0
# chr1:21720782:C:T  0.139294  447457.0  1749.805584     1764.0      445693.0
# chr1:21722171:C:T  0.145277  413317.0  1585.664794     1599.0      411718.0
# chr1:21772447:C:T  0.138653  447457.0  1749.805584     1764.0      445693.0
# chr1:21772448:C:T  0.000141   77092.0   740.322759      749.0       76343.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.342698  447457.0  1749.805584     1764.0      445693.0
# chr19:8702698:C:T  0.341194  447457.0  1749.805584     1764.0      445693.0
# chr19:8703043:G:A  0.340990  447457.0  1749.805584     1764.0      445693.0
# chr19:8703125:G:T  0.619177  447457.0  1749.805584     1764.0      445693.0
# chr19:8704019:C:T  0.144614  413317.0  1585.664794     1599.0      411718.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.003942  1757.045821
# chr1:21720782:C:T  0.003942  1757.045821
# chr1:21722171:C:T  0.003869  1592.813947
# chr1:21772447:C:T  0.003942  1757.045821
# chr1:21772448:C:T  0.009716   741.722967
# ...                     ...          ...
# chr19:8697017:A:T  0.003942  1757.045821
# chr19:8702698:C:T  0.003942  1757.045821
# chr19:8703043:G:A  0.003942  1757.045821
# chr19:8703125:G:T  0.003942  1757.045821
# chr19:8704019:C:T  0.003869  1592.813947
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_1.txt Meta_Input/UKBB_EUR.cluster_vs_controls_1.txt Meta_Input/PMBB_EUR.cluster_vs_controls_1.txt Meta_Input/AOU_EUR.cluster_vs_controls_1.txt Meta_Input/BioVU_EUR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9841 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.005923  447457.0  1749.805584     1764.0      445693.0
# chr1:21720782:C:T  0.005477  447457.0  1749.805584     1764.0      445693.0
# chr1:21722171:C:T  0.004253  413317.0  1585.664794     1599.0      411718.0
# chr1:21772447:C:T  0.005443  447457.0  1749.805584     1764.0      445693.0
# chr1:21772448:C:T  0.008142   77092.0   740.322759      749.0       76343.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.030426  447457.0  1749.805584     1764.0      445693.0
# chr19:8702698:C:T  0.030240  447457.0  1749.805584     1764.0      445693.0
# chr19:8703043:G:A  0.030241  447457.0  1749.805584     1764.0      445693.0
# chr19:8703125:G:T  0.065447  447457.0  1749.805584     1764.0      445693.0
# chr19:8704019:C:T  0.007649  413317.0  1585.664794     1599.0      411718.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.003942  1757.045821
# chr1:21720782:C:T  0.003942  1757.045821
# chr1:21722171:C:T  0.003869  1592.813947
# chr1:21772447:C:T  0.003942  1757.045821
# chr1:21772448:C:T  0.009716   741.722967
# ...                     ...          ...
# chr19:8697017:A:T  0.003942  1757.045821
# chr19:8702698:C:T  0.003942  1757.045821
# chr19:8703043:G:A  0.003942  1757.045821
# chr19:8703125:G:T  0.003942  1757.045821
# chr19:8704019:C:T  0.003869  1592.813947
#
# [10494 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_1.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_1.txt Meta_Input/UKBB_AFR.cluster_vs_controls_1.txt Meta_Input/PMBB_AFR.cluster_vs_controls_1.txt Meta_Input/AOU_AFR.cluster_vs_controls_1.txt Meta_Input/BioVU_AFR.cluster_vs_controls_1.txt
#   --out Meta_Output/cluster_vs_controls_1.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10320 variants processed; results written to
# Meta_Output/cluster_vs_controls_1.AFR.PLINK.meta .
# cluster_vs_controls_2
# 	 ALL
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142915  447941.0  2206.998550     2225.0      445716.0
# chr1:21720782:C:T  0.144733  447941.0  2206.998550     2225.0      445716.0
# chr1:21722171:C:T  0.149512  413705.0  1948.457573     1964.0      411741.0
# chr1:21772447:C:T  0.144053  447941.0  2206.998550     2225.0      445716.0
# chr1:21772448:C:T  0.008325   77130.0   857.848444      869.0       76261.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.372994  447941.0  2206.998550     2225.0      445716.0
# chr19:8702698:C:T  0.371309  447941.0  2206.998550     2225.0      445716.0
# chr19:8703043:G:A  0.371105  447941.0  2206.998550     2225.0      445716.0
# chr19:8703125:G:T  0.684518  447941.0  2206.998550     2225.0      445716.0
# chr19:8704019:C:T  0.152265  413705.0  1948.457573     1964.0      411741.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.004967  2213.948042
# chr1:21720782:C:T  0.004967  2213.948042
# chr1:21722171:C:T  0.004747  1954.676216
# chr1:21772447:C:T  0.004967  2213.948042
# chr1:21772448:C:T  0.011267   859.209244
# ...                     ...          ...
# chr19:8697017:A:T  0.004967  2213.948042
# chr19:8702698:C:T  0.004967  2213.948042
# chr19:8703043:G:A  0.004967  2213.948042
# chr19:8703125:G:T  0.004967  2213.948042
# chr19:8704019:C:T  0.004747  1954.676216
#
# [10495 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_AFR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_ASIAN.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt Meta_Input/BioVU_AFR.cluster_vs_controls_2.txt Meta_Input/BioVU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10495 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142915  447941.0  2206.998550     2225.0      445716.0
# chr1:21720782:C:T  0.144733  447941.0  2206.998550     2225.0      445716.0
# chr1:21722171:C:T  0.149512  413705.0  1948.457573     1964.0      411741.0
# chr1:21772447:C:T  0.144053  447941.0  2206.998550     2225.0      445716.0
# chr1:21772448:C:T  0.008325   77130.0   857.848444      869.0       76261.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.372994  447941.0  2206.998550     2225.0      445716.0
# chr19:8702698:C:T  0.371309  447941.0  2206.998550     2225.0      445716.0
# chr19:8703043:G:A  0.371105  447941.0  2206.998550     2225.0      445716.0
# chr19:8703125:G:T  0.684518  447941.0  2206.998550     2225.0      445716.0
# chr19:8704019:C:T  0.152265  413705.0  1948.457573     1964.0      411741.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.004967  2213.948042
# chr1:21720782:C:T  0.004967  2213.948042
# chr1:21722171:C:T  0.004747  1954.676216
# chr1:21772447:C:T  0.004967  2213.948042
# chr1:21772448:C:T  0.011267   859.209244
# ...                     ...          ...
# chr19:8697017:A:T  0.004967  2213.948042
# chr19:8702698:C:T  0.004967  2213.948042
# chr19:8703043:G:A  0.004967  2213.948042
# chr19:8703125:G:T  0.004967  2213.948042
# chr19:8704019:C:T  0.004747  1954.676216
#
# [10495 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_AFR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt Meta_Input/BioVU_AFR.cluster_vs_controls_2.txt Meta_Input/BioVU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10495 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.136988  447941.0  2206.998550     2225.0      445716.0
# chr1:21720782:C:T  0.139253  447941.0  2206.998550     2225.0      445716.0
# chr1:21722171:C:T  0.145251  413705.0  1948.457573     1964.0      411741.0
# chr1:21772447:C:T  0.138609  447941.0  2206.998550     2225.0      445716.0
# chr1:21772448:C:T  0.000140   77130.0   857.848444      869.0       76261.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.342576  447941.0  2206.998550     2225.0      445716.0
# chr19:8702698:C:T  0.341071  447941.0  2206.998550     2225.0      445716.0
# chr19:8703043:G:A  0.340867  447941.0  2206.998550     2225.0      445716.0
# chr19:8703125:G:T  0.619033  447941.0  2206.998550     2225.0      445716.0
# chr19:8704019:C:T  0.144602  413705.0  1948.457573     1964.0      411741.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.004967  2213.948042
# chr1:21720782:C:T  0.004967  2213.948042
# chr1:21722171:C:T  0.004747  1954.676216
# chr1:21772447:C:T  0.004967  2213.948042
# chr1:21772448:C:T  0.011267   859.209244
# ...                     ...          ...
# chr19:8697017:A:T  0.004967  2213.948042
# chr19:8702698:C:T  0.004967  2213.948042
# chr19:8703043:G:A  0.004967  2213.948042
# chr19:8703125:G:T  0.004967  2213.948042
# chr19:8704019:C:T  0.004747  1954.676216
#
# [10495 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_2.txt Meta_Input/UKBB_EUR.cluster_vs_controls_2.txt Meta_Input/PMBB_EUR.cluster_vs_controls_2.txt Meta_Input/AOU_EUR.cluster_vs_controls_2.txt Meta_Input/BioVU_EUR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9840 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.005927  447941.0  2206.998550     2225.0      445716.0
# chr1:21720782:C:T  0.005480  447941.0  2206.998550     2225.0      445716.0
# chr1:21722171:C:T  0.004261  413705.0  1948.457573     1964.0      411741.0
# chr1:21772447:C:T  0.005444  447941.0  2206.998550     2225.0      445716.0
# chr1:21772448:C:T  0.008184   77130.0   857.848444      869.0       76261.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.030418  447941.0  2206.998550     2225.0      445716.0
# chr19:8702698:C:T  0.030238  447941.0  2206.998550     2225.0      445716.0
# chr19:8703043:G:A  0.030238  447941.0  2206.998550     2225.0      445716.0
# chr19:8703125:G:T  0.065485  447941.0  2206.998550     2225.0      445716.0
# chr19:8704019:C:T  0.007663  413705.0  1948.457573     1964.0      411741.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.004967  2213.948042
# chr1:21720782:C:T  0.004967  2213.948042
# chr1:21722171:C:T  0.004747  1954.676216
# chr1:21772447:C:T  0.004967  2213.948042
# chr1:21772448:C:T  0.011267   859.209244
# ...                     ...          ...
# chr19:8697017:A:T  0.004967  2213.948042
# chr19:8702698:C:T  0.004967  2213.948042
# chr19:8703043:G:A  0.004967  2213.948042
# chr19:8703125:G:T  0.004967  2213.948042
# chr19:8704019:C:T  0.004747  1954.676216
#
# [10495 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_2.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_2.txt Meta_Input/UKBB_AFR.cluster_vs_controls_2.txt Meta_Input/PMBB_AFR.cluster_vs_controls_2.txt Meta_Input/AOU_AFR.cluster_vs_controls_2.txt Meta_Input/BioVU_AFR.cluster_vs_controls_2.txt
#   --out Meta_Output/cluster_vs_controls_2.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10321 variants processed; results written to
# Meta_Output/cluster_vs_controls_2.AFR.PLINK.meta .
# cluster_vs_controls_3
# 	 ALL
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142932  448071.0  2371.543698     2388.0      445683.0
# chr1:21720782:C:T  0.144763  448071.0  2371.543698     2388.0      445683.0
# chr1:21722171:C:T  0.149538  413846.0  2123.376466     2138.0      411708.0
# chr1:21772447:C:T  0.144096  448071.0  2371.543698     2388.0      445683.0
# chr1:21772448:C:T  0.008296   76959.0   590.539419      596.0       76363.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373103  448071.0  2371.543698     2388.0      445683.0
# chr19:8702698:C:T  0.371413  448071.0  2371.543698     2388.0      445683.0
# chr19:8703043:G:A  0.371211  448071.0  2371.543698     2388.0      445683.0
# chr19:8703125:G:T  0.684593  448071.0  2371.543698     2388.0      445683.0
# chr19:8704019:C:T  0.152268  413846.0  2123.376466     2138.0      411708.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005330  2375.273124
# chr1:21720782:C:T  0.005330  2375.273124
# chr1:21722171:C:T  0.005166  2126.954722
# chr1:21772447:C:T  0.005330  2375.273124
# chr1:21772448:C:T  0.007744   591.384348
# ...                     ...          ...
# chr19:8697017:A:T  0.005330  2375.273124
# chr19:8702698:C:T  0.005330  2375.273124
# chr19:8703043:G:A  0.005330  2375.273124
# chr19:8703125:G:T  0.005330  2375.273124
# chr19:8704019:C:T  0.005166  2126.954722
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_AFR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_ASIAN.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt Meta_Input/BioVU_AFR.cluster_vs_controls_3.txt Meta_Input/BioVU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142932  448071.0  2371.543698     2388.0      445683.0
# chr1:21720782:C:T  0.144763  448071.0  2371.543698     2388.0      445683.0
# chr1:21722171:C:T  0.149538  413846.0  2123.376466     2138.0      411708.0
# chr1:21772447:C:T  0.144096  448071.0  2371.543698     2388.0      445683.0
# chr1:21772448:C:T  0.008296   76959.0   590.539419      596.0       76363.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373103  448071.0  2371.543698     2388.0      445683.0
# chr19:8702698:C:T  0.371413  448071.0  2371.543698     2388.0      445683.0
# chr19:8703043:G:A  0.371211  448071.0  2371.543698     2388.0      445683.0
# chr19:8703125:G:T  0.684593  448071.0  2371.543698     2388.0      445683.0
# chr19:8704019:C:T  0.152268  413846.0  2123.376466     2138.0      411708.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005330  2375.273124
# chr1:21720782:C:T  0.005330  2375.273124
# chr1:21722171:C:T  0.005166  2126.954722
# chr1:21772447:C:T  0.005330  2375.273124
# chr1:21772448:C:T  0.007744   591.384348
# ...                     ...          ...
# chr19:8697017:A:T  0.005330  2375.273124
# chr19:8702698:C:T  0.005330  2375.273124
# chr19:8703043:G:A  0.005330  2375.273124
# chr19:8703125:G:T  0.005330  2375.273124
# chr19:8704019:C:T  0.005166  2126.954722
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_AFR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt Meta_Input/BioVU_AFR.cluster_vs_controls_3.txt Meta_Input/BioVU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10497 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.137023  448071.0  2371.543698     2388.0      445683.0
# chr1:21720782:C:T  0.139303  448071.0  2371.543698     2388.0      445683.0
# chr1:21722171:C:T  0.145294  413846.0  2123.376466     2138.0      411708.0
# chr1:21772447:C:T  0.138671  448071.0  2371.543698     2388.0      445683.0
# chr1:21772448:C:T  0.000141   76959.0   590.539419      596.0       76363.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.342749  448071.0  2371.543698     2388.0      445683.0
# chr19:8702698:C:T  0.341243  448071.0  2371.543698     2388.0      445683.0
# chr19:8703043:G:A  0.341040  448071.0  2371.543698     2388.0      445683.0
# chr19:8703125:G:T  0.619319  448071.0  2371.543698     2388.0      445683.0
# chr19:8704019:C:T  0.144631  413846.0  2123.376466     2138.0      411708.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005330  2375.273124
# chr1:21720782:C:T  0.005330  2375.273124
# chr1:21722171:C:T  0.005166  2126.954722
# chr1:21772447:C:T  0.005330  2375.273124
# chr1:21772448:C:T  0.007744   591.384348
# ...                     ...          ...
# chr19:8697017:A:T  0.005330  2375.273124
# chr19:8702698:C:T  0.005330  2375.273124
# chr19:8703043:G:A  0.005330  2375.273124
# chr19:8703125:G:T  0.005330  2375.273124
# chr19:8704019:C:T  0.005166  2126.954722
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_3.txt Meta_Input/UKBB_EUR.cluster_vs_controls_3.txt Meta_Input/PMBB_EUR.cluster_vs_controls_3.txt Meta_Input/AOU_EUR.cluster_vs_controls_3.txt Meta_Input/BioVU_EUR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9845 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.005908  448071.0  2371.543698     2388.0      445683.0
# chr1:21720782:C:T  0.005461  448071.0  2371.543698     2388.0      445683.0
# chr1:21722171:C:T  0.004243  413846.0  2123.376466     2138.0      411708.0
# chr1:21772447:C:T  0.005425  448071.0  2371.543698     2388.0      445683.0
# chr1:21772448:C:T  0.008155   76959.0   590.539419      596.0       76363.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.030354  448071.0  2371.543698     2388.0      445683.0
# chr19:8702698:C:T  0.030170  448071.0  2371.543698     2388.0      445683.0
# chr19:8703043:G:A  0.030172  448071.0  2371.543698     2388.0      445683.0
# chr19:8703125:G:T  0.065275  448071.0  2371.543698     2388.0      445683.0
# chr19:8704019:C:T  0.007637  413846.0  2123.376466     2138.0      411708.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005330  2375.273124
# chr1:21720782:C:T  0.005330  2375.273124
# chr1:21722171:C:T  0.005166  2126.954722
# chr1:21772447:C:T  0.005330  2375.273124
# chr1:21772448:C:T  0.007744   591.384348
# ...                     ...          ...
# chr19:8697017:A:T  0.005330  2375.273124
# chr19:8702698:C:T  0.005330  2375.273124
# chr19:8703043:G:A  0.005330  2375.273124
# chr19:8703125:G:T  0.005330  2375.273124
# chr19:8704019:C:T  0.005166  2126.954722
#
# [10497 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_3.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_3.txt Meta_Input/UKBB_AFR.cluster_vs_controls_3.txt Meta_Input/PMBB_AFR.cluster_vs_controls_3.txt Meta_Input/AOU_AFR.cluster_vs_controls_3.txt Meta_Input/BioVU_AFR.cluster_vs_controls_3.txt
#   --out Meta_Output/cluster_vs_controls_3.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10323 variants processed; results written to
# Meta_Output/cluster_vs_controls_3.AFR.PLINK.meta .
# cluster_vs_controls_4
# 	 ALL
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142944  447899.0  2249.815969     2276.0      445623.0
# chr1:21720782:C:T  0.144773  447899.0  2249.815969     2276.0      445623.0
# chr1:21722171:C:T  0.149540  413736.0  2062.854765     2088.0      411648.0
# chr1:21772447:C:T  0.144106  447899.0  2249.815969     2276.0      445623.0
# chr1:21772448:C:T  0.008274   77355.0  1037.004214     1055.0       76300.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373030  447899.0  2249.815969     2276.0      445623.0
# chr19:8702698:C:T  0.371348  447899.0  2249.815969     2276.0      445623.0
# chr19:8703043:G:A  0.371142  447899.0  2249.815969     2276.0      445623.0
# chr19:8703125:G:T  0.684600  447899.0  2249.815969     2276.0      445623.0
# chr19:8704019:C:T  0.152280  413736.0  2062.854765     2088.0      411648.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005082  2264.434500
# chr1:21720782:C:T  0.005082  2264.434500
# chr1:21722171:C:T  0.005047  2077.462498
# chr1:21772447:C:T  0.005082  2264.434500
# chr1:21772448:C:T  0.013638  1040.611467
# ...                     ...          ...
# chr19:8697017:A:T  0.005082  2264.434500
# chr19:8702698:C:T  0.005082  2264.434500
# chr19:8703043:G:A  0.005082  2264.434500
# chr19:8703125:G:T  0.005082  2264.434500
# chr19:8704019:C:T  0.005047  2077.462498
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt Meta_Input/BioVU_AFR.cluster_vs_controls_4.txt Meta_Input/BioVU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.142944  447899.0  2249.815969     2276.0      445623.0
# chr1:21720782:C:T  0.144773  447899.0  2249.815969     2276.0      445623.0
# chr1:21722171:C:T  0.149540  413736.0  2062.854765     2088.0      411648.0
# chr1:21772447:C:T  0.144106  447899.0  2249.815969     2276.0      445623.0
# chr1:21772448:C:T  0.008274   77355.0  1037.004214     1055.0       76300.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.373030  447899.0  2249.815969     2276.0      445623.0
# chr19:8702698:C:T  0.371348  447899.0  2249.815969     2276.0      445623.0
# chr19:8703043:G:A  0.371142  447899.0  2249.815969     2276.0      445623.0
# chr19:8703125:G:T  0.684600  447899.0  2249.815969     2276.0      445623.0
# chr19:8704019:C:T  0.152280  413736.0  2062.854765     2088.0      411648.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005082  2264.434500
# chr1:21720782:C:T  0.005082  2264.434500
# chr1:21722171:C:T  0.005047  2077.462498
# chr1:21772447:C:T  0.005082  2264.434500
# chr1:21772448:C:T  0.013638  1040.611467
# ...                     ...          ...
# chr19:8697017:A:T  0.005082  2264.434500
# chr19:8702698:C:T  0.005082  2264.434500
# chr19:8703043:G:A  0.005082  2264.434500
# chr19:8703125:G:T  0.005082  2264.434500
# chr19:8704019:C:T  0.005047  2077.462498
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt Meta_Input/BioVU_AFR.cluster_vs_controls_4.txt Meta_Input/BioVU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10496 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.137021  447899.0  2249.815969     2276.0      445623.0
# chr1:21720782:C:T  0.139300  447899.0  2249.815969     2276.0      445623.0
# chr1:21722171:C:T  0.145289  413736.0  2062.854765     2088.0      411648.0
# chr1:21772447:C:T  0.138665  447899.0  2249.815969     2276.0      445623.0
# chr1:21772448:C:T  0.000140   77355.0  1037.004214     1055.0       76300.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.342590  447899.0  2249.815969     2276.0      445623.0
# chr19:8702698:C:T  0.341093  447899.0  2249.815969     2276.0      445623.0
# chr19:8703043:G:A  0.340886  447899.0  2249.815969     2276.0      445623.0
# chr19:8703125:G:T  0.619101  447899.0  2249.815969     2276.0      445623.0
# chr19:8704019:C:T  0.144617  413736.0  2062.854765     2088.0      411648.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005082  2264.434500
# chr1:21720782:C:T  0.005082  2264.434500
# chr1:21722171:C:T  0.005047  2077.462498
# chr1:21772447:C:T  0.005082  2264.434500
# chr1:21772448:C:T  0.013638  1040.611467
# ...                     ...          ...
# chr19:8697017:A:T  0.005082  2264.434500
# chr19:8702698:C:T  0.005082  2264.434500
# chr19:8703043:G:A  0.005082  2264.434500
# chr19:8703125:G:T  0.005082  2264.434500
# chr19:8704019:C:T  0.005047  2077.462498
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_4.txt Meta_Input/UKBB_EUR.cluster_vs_controls_4.txt Meta_Input/PMBB_EUR.cluster_vs_controls_4.txt Meta_Input/AOU_EUR.cluster_vs_controls_4.txt Meta_Input/BioVU_EUR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9844 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.005922  447899.0  2249.815969     2276.0      445623.0
# chr1:21720782:C:T  0.005473  447899.0  2249.815969     2276.0      445623.0
# chr1:21722171:C:T  0.004251  413736.0  2062.854765     2088.0      411648.0
# chr1:21772447:C:T  0.005441  447899.0  2249.815969     2276.0      445623.0
# chr1:21772448:C:T  0.008134   77355.0  1037.004214     1055.0       76300.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.030440  447899.0  2249.815969     2276.0      445623.0
# chr19:8702698:C:T  0.030255  447899.0  2249.815969     2276.0      445623.0
# chr19:8703043:G:A  0.030256  447899.0  2249.815969     2276.0      445623.0
# chr19:8703125:G:T  0.065499  447899.0  2249.815969     2276.0      445623.0
# chr19:8704019:C:T  0.007663  413736.0  2062.854765     2088.0      411648.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.005082  2264.434500
# chr1:21720782:C:T  0.005082  2264.434500
# chr1:21722171:C:T  0.005047  2077.462498
# chr1:21772447:C:T  0.005082  2264.434500
# chr1:21772448:C:T  0.013638  1040.611467
# ...                     ...          ...
# chr19:8697017:A:T  0.005082  2264.434500
# chr19:8702698:C:T  0.005082  2264.434500
# chr19:8703043:G:A  0.005082  2264.434500
# chr19:8703125:G:T  0.005082  2264.434500
# chr19:8704019:C:T  0.005047  2077.462498
#
# [10496 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_4.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_AFR.cluster_vs_controls_4.txt Meta_Input/PMBB_AFR.cluster_vs_controls_4.txt Meta_Input/AOU_AFR.cluster_vs_controls_4.txt Meta_Input/BioVU_AFR.cluster_vs_controls_4.txt
#   --out Meta_Output/cluster_vs_controls_4.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10322 variants processed; results written to
# Meta_Output/cluster_vs_controls_4.AFR.PLINK.meta .
# cluster_vs_controls_5
# 	 ALL
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.144924  444492.0  3355.114045     3385.0      441107.0
# chr1:21720782:C:T  0.146878  444492.0  3355.114045     3385.0      441107.0
# chr1:21722171:C:T  0.152117  410291.0  3130.636658     3159.0      407132.0
# chr1:21772447:C:T  0.146168  444492.0  3355.114045     3385.0      441107.0
# chr1:21772448:C:T  0.007152   63248.0   178.373726      179.0       63069.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.377347  444492.0  3355.114045     3385.0      441107.0
# chr19:8702698:C:T  0.375583  444492.0  3355.114045     3385.0      441107.0
# chr19:8703043:G:A  0.375365  444492.0  3355.114045     3385.0      441107.0
# chr19:8703125:G:T  0.687919  444492.0  3355.114045     3385.0      441107.0
# chr19:8704019:C:T  0.153529  410291.0  3130.636658     3159.0      407132.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.007615  3359.221752
# chr1:21720782:C:T  0.007615  3359.221752
# chr1:21722171:C:T  0.007699  3134.677553
# chr1:21772447:C:T  0.007615  3359.221752
# chr1:21772448:C:T  0.002830   178.493407
# ...                     ...          ...
# chr19:8697017:A:T  0.007615  3359.221752
# chr19:8702698:C:T  0.007615  3359.221752
# chr19:8703043:G:A  0.007615  3359.221752
# chr19:8703125:G:T  0.007615  3359.221752
# chr19:8704019:C:T  0.007699  3134.677553
#
# [10432 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.ALL.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_ASIAN.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt Meta_Input/BioVU_AFR.cluster_vs_controls_5.txt Meta_Input/BioVU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.ALL.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10432 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.ALL.PLINK.meta .
# 	 AFR_EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.143303  444492.0  3355.114045     3385.0      441107.0
# chr1:21720782:C:T  0.145255  444492.0  3355.114045     3385.0      441107.0
# chr1:21722171:C:T  0.150367  410291.0  3130.636658     3159.0      407132.0
# chr1:21772447:C:T  0.144566  444492.0  3355.114045     3385.0      441107.0
# chr1:21772448:C:T  0.007152   63248.0   178.373726      179.0       63069.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.371298  444492.0  3355.114045     3385.0      441107.0
# chr19:8702698:C:T  0.369685  444492.0  3355.114045     3385.0      441107.0
# chr19:8703043:G:A  0.369471  444492.0  3355.114045     3385.0      441107.0
# chr19:8703125:G:T  0.680003  444492.0  3355.114045     3385.0      441107.0
# chr19:8704019:C:T  0.152128  410291.0  3130.636658     3159.0      407132.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.007615  3359.221752
# chr1:21720782:C:T  0.007615  3359.221752
# chr1:21722171:C:T  0.007699  3134.677553
# chr1:21772447:C:T  0.007615  3359.221752
# chr1:21772448:C:T  0.002830   178.493407
# ...                     ...          ...
# chr19:8697017:A:T  0.007615  3359.221752
# chr19:8702698:C:T  0.007615  3359.221752
# chr19:8703043:G:A  0.007615  3359.221752
# chr19:8703125:G:T  0.007615  3359.221752
# chr19:8704019:C:T  0.007699  3134.677553
#
# [10432 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt Meta_Input/BioVU_AFR.cluster_vs_controls_5.txt Meta_Input/BioVU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10323 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.AFR_EUR.PLINK.meta .
# 	 EUR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.138748  444492.0  3355.114045     3385.0      441107.0
# chr1:21720782:C:T  0.141054  444492.0  3355.114045     3385.0      441107.0
# chr1:21722171:C:T  0.147233  410291.0  3130.636658     3159.0      407132.0
# chr1:21772447:C:T  0.140403  444492.0  3355.114045     3385.0      441107.0
# chr1:21772448:C:T  0.000172   63248.0   178.373726      179.0       63069.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.346789  444492.0  3355.114045     3385.0      441107.0
# chr19:8702698:C:T  0.345273  444492.0  3355.114045     3385.0      441107.0
# chr19:8703043:G:A  0.345064  444492.0  3355.114045     3385.0      441107.0
# chr19:8703125:G:T  0.626636  444492.0  3355.114045     3385.0      441107.0
# chr19:8704019:C:T  0.146491  410291.0  3130.636658     3159.0      407132.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.007615  3359.221752
# chr1:21720782:C:T  0.007615  3359.221752
# chr1:21722171:C:T  0.007699  3134.677553
# chr1:21772447:C:T  0.007615  3359.221752
# chr1:21772448:C:T  0.002830   178.493407
# ...                     ...          ...
# chr19:8697017:A:T  0.007615  3359.221752
# chr19:8702698:C:T  0.007615  3359.221752
# chr19:8703043:G:A  0.007615  3359.221752
# chr19:8703125:G:T  0.007615  3359.221752
# chr19:8704019:C:T  0.007699  3134.677553
#
# [10432 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.EUR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/eMERGE_EUR.cluster_vs_controls_5.txt Meta_Input/UKBB_EUR.cluster_vs_controls_5.txt Meta_Input/PMBB_EUR.cluster_vs_controls_5.txt Meta_Input/AOU_EUR.cluster_vs_controls_5.txt Meta_Input/BioVU_EUR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.EUR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 9816 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.EUR.PLINK.meta .
# 	 AFR
#                     Meta_AF         N     Neff_sum  Cases_sum  Controls_sum  \
# ID
# chr1:21686033:C:T  0.004555  444492.0  3355.114045     3385.0      441107.0
# chr1:21720782:C:T  0.004201  444492.0  3355.114045     3385.0      441107.0
# chr1:21722171:C:T  0.003134  410291.0  3130.636658     3159.0      407132.0
# chr1:21772447:C:T  0.004164  444492.0  3355.114045     3385.0      441107.0
# chr1:21772448:C:T  0.006980   63248.0   178.373726      179.0       63069.0
# ...                     ...       ...          ...        ...           ...
# chr19:8697017:A:T  0.024509  444492.0  3355.114045     3385.0      441107.0
# chr19:8702698:C:T  0.024412  444492.0  3355.114045     3385.0      441107.0
# chr19:8703043:G:A  0.024407  444492.0  3355.114045     3385.0      441107.0
# chr19:8703125:G:T  0.053367  444492.0  3355.114045     3385.0      441107.0
# chr19:8704019:C:T  0.005637  410291.0  3130.636658     3159.0      407132.0
#
#                         Phi    Neff_meta
# ID
# chr1:21686033:C:T  0.007615  3359.221752
# chr1:21720782:C:T  0.007615  3359.221752
# chr1:21722171:C:T  0.007699  3134.677553
# chr1:21772447:C:T  0.007615  3359.221752
# chr1:21772448:C:T  0.002830   178.493407
# ...                     ...          ...
# chr19:8697017:A:T  0.007615  3359.221752
# chr19:8702698:C:T  0.007615  3359.221752
# chr19:8703043:G:A  0.007615  3359.221752
# chr19:8703125:G:T  0.007615  3359.221752
# chr19:8704019:C:T  0.007699  3134.677553
#
# [10432 rows x 7 columns]
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Meta_Output/cluster_vs_controls_5.AFR.PLINK.log.
# Options in effect:
#   --meta-analysis Meta_Input/UKBB_AFR.cluster_vs_controls_5.txt Meta_Input/AOU_AFR.cluster_vs_controls_5.txt Meta_Input/BioVU_AFR.cluster_vs_controls_5.txt
#   --out Meta_Output/cluster_vs_controls_5.AFR.PLINK
#
# 515273 MB RAM detected; reserving 257636 MB for main workspace.
# --meta-analysis: 10206 variants processed; results written to
# Meta_Output/cluster_vs_controls_5.AFR.PLINK.meta .
